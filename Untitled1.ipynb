# %% [markdown]
# ordered and indexed
# immutable
# use()

# %%
ages=(22,1,20,25)
stu=(102,"sam",30,"it")
mt=()

# %%
print(type(mt))
# Out:
# <class 'tuple'>

# %%
s=(10,)

# %%
print(type(s))
# Out:
# <class 'tuple'>

# %%
print(stu[0])
# Out:
# 102

# %%
print(stu[-1])
# Out:
# it

# %%
print(stu[1:3])
# Out:
# ('arsha', 30)

# %%
print(stu)
# Out:
# (102, 'arsha', 30, 'it')

# %%
stu=(102,"arsha",30,"it")
print(stu)
# Out:
# (102, 'arsha', 30, 'it')

# %%
t1=(1,2)
t2=(1,4)
t3=(3,6)
t4=t1+t2+t3
print(t4)
# Out:
# (1, 2, 1, 4, 3, 6)

# %%
data=(1,54,60,4)
del data

# %%
val=(1,4,6,7)
print(len(val))
# Out:
# 4

# %%
print(val.index(6))
# Out:
# 2

# %%
print(7 in val)
# Out:
# True

# %%
t=(9,8,7)
print(60 not in t)
# Out:
# True

# %%
print(t*3)
# Out:
# (9, 8, 7, 9, 8, 7, 9, 8, 7)

# %%
print(min(t))
print(max(t))
# Out:
# 7
# 9

# %%
print(sum(t))
# Out:
# 24

# %%
res=sorted(t)
print(res)
# Out:
# [7, 8, 9]

# %%
text="GLA"
print(tuple(text))
# Out:
# ('G', 'L', 'A')

# %%
lst =[10,20,30,40]
print(type(lst))
# Out:
# <class 'list'>
# (10, 20, 30, 40)
# <class 'tuple'>
